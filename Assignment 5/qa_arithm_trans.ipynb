# %%
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup
import torch

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import defaultdict
from textwrap import wrap

from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# Splits data into batches of defined size
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from tqdm import tqdm

import random, os

# %%
test_dataset = 'SampleTestFile.xlsx'
df = pd.read_excel(test_dataset)

testdataset = []
vocab, vocab_target = [], []
for idx, row in enumerate(df.iterrows()):
    if idx == 0:
        print(row[1][0], row[1][1], row[1][2])
        continue
# Out:
# number0 red apples and number1 green apples are in the basket . how many apples are in the basket ? 7 2

# %%
def set_seed(seed = 42):
    '''
        For Reproducibility: Sets the seed of the entire notebook.
    '''

    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
    # Sets a fixed value for the hash seed
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(1)

# %%
file_errors_location = 'ArithOpsTrain.xlsx'
df = pd.read_excel(file_errors_location)

# %%
from torchtext.data import get_tokenizer

# Downloads GloVe and FastText
#global_vectors = GloVe(name='840B', dim=300)

# ----------- Text Preprocessing -----------
#nlp = spacy.load("en_core_web_md")
tokenizer = get_tokenizer("basic_english")

# Define special symbols and indices
UNK_IDX, PAD_IDX, BOS_IDX, EOS_IDX = 0, 1, 2, 3
# Make sure the tokens are in order of their indices to properly insert them in vocab
special_symbols = ['<unk>', '<pad>', '<bos>', '<eos>']

# %%
dataset = []
vocab, vocab_target = [], []
for idx, row in enumerate(df.iterrows()):
    if idx == 0:
        print(row[1][1], row[1][2], row[1][3], row[1][4], row[1][5])
        continue 
    
    context = tokenizer(row[1][1])
    vocab.extend(context)
    
    ques = tokenizer(row[1][2])
    vocab.extend(ques)

    ans = tokenizer(row[1][3])
    vocab_target.extend(ans)

    ip = [float(x) for x in row[1][4].split()]
    out = float(row[1][5])
    dataset.append((context, ques, ans, ip, out))
# Out:
# Description Question Equation Input Numbers Output

# %%
vocab_to_id = {}
ids = 1
for word in vocab:
    if word not in vocab_to_id:
        vocab_to_id[word] = ids
        ids += 1

vocab_target_to_id = {}
idt = 1
for word in vocab_target:
    if word not in vocab_target_to_id:
        vocab_target_to_id[word] = idt
        idt += 1

print(ids, idt)
# Out:
# 2617 10

# %%
dataset_tokenized = []

for context, ques, ans, ip, out in dataset:
    context_token = []
    for word in context:
        context_token.append(vocab_to_id[word])
    
    ques_token = []
    for word in ques:
        ques_token.append(vocab_to_id[word])

    ans_token = []
    for word in ans:
        ans_token.append(vocab_target_to_id[word])
    
    dataset_tokenized.append((context_token, ques_token, ans_token, ip, out))

# %%
dataset_tokenized[0]
# Out:
# ([1, 2, 3, 4, 5, 6, 7, 8, 9, 4, 5, 6],
#  [10, 11, 12, 13, 14, 15, 4, 5, 16],
#  [1, 2, 3],
#  [63.0, 50.0],
#  113.0)

# %%
def split_indices(n, val_pct):

    # Determine size of Validation set
    n_val = int(val_pct * n)

    # Create random permutation of 0 to n-1
    idxs = np.random.permutation(n)
    return idxs[n_val:], idxs[:n_val]

train_indices, val_indices = split_indices(len(dataset), 0.2)

# %%
from torch.nn.utils.rnn import pad_sequence

# ----------- Batching the data -----------
def collate_fn(instn):
    context = [torch.Tensor(x[1] +[ids] + x[0]) for x in instn]
    ques = [torch.Tensor(x[1]) for x in instn]
    ans = [torch.Tensor([idt+1] + x[2] + [idt]) for x in instn]
    ip = [x[3] for x in instn]
    out = [x[4] for x in instn]

    context_pad = pad_sequence(context, batch_first=True, padding_value=0).long()
    ques_pad = pad_sequence(ques, batch_first=True, padding_value=0).long()
    ans_pad = pad_sequence(ans, batch_first=True, padding_value=0).long()

    return (context_pad, ques_pad, ans_pad, ip, out)


batch_size = 128

train_sampler   = SubsetRandomSampler(train_indices)
train_loader    = DataLoader(dataset_tokenized, batch_size, sampler=train_sampler, collate_fn=collate_fn)

val_sampler     = SubsetRandomSampler(val_indices)
val_loader      = DataLoader(dataset_tokenized, batch_size, sampler=val_sampler, collate_fn=collate_fn)

# %%
for i in train_loader:
    print(i)
    break
# Out:
# (tensor([[  10,  128,  129,  ...,    0,    0,    0],
#         [  27,   28,  279,  ...,    0,    0,    0],
#         [  27,   28,   39,  ...,    0,    0,    0],
#         ...,
#         [  27,   28,   92,  ...,    0,    0,    0],
#         [  27,   28, 1876,  ...,    0,    0,    0],
#         [  27,   28,  740,  ...,    0,    0,    0]]), tensor([[  10,  128,  129,  ...,    0,    0,    0],
#         [  27,   28,  279,  ...,    0,    0,    0],
#         [  27,   28,   39,  ...,    0,    0,    0],
#         ...,
#         [  27,   28,   92,  ...,    0,    0,    0],
#         [  27,   28, 1876,  ...,    0,    0,    0],
#         [  27,   28,  740,  ...,    0,    0,    0]]), tensor([[11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  4,  2,  3,  5, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  8,  3,  2, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  4,  3,  2, 10,  0,  0],
#         [11,  4,  5,  2, 10,  0,  0],
#         [11,  4,  1,  2,  3,  5, 10],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  1,  2,  3,  5, 10],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  3,  2, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  1,  3,  5,  7, 10],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  4,  2,  3,  5, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  1,  5,  7, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  5,  2, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  5,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  3,  2, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  8,  3,  5, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  1,  8,  3,  5,  2, 10],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  1,  2,  3,  5, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  3,  2, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  1,  1,  3,  5,  7, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  1,  8,  2,  3,  5, 10],
#         [11,  4,  3,  2, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  1,  2,  3,  5, 10],
#         [11,  1,  5,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  4,  2,  3,  5, 10],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  5, 10,  0,  0],
#         [11,  4,  4,  2,  3,  5, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  3,  2, 10,  0,  0],
#         [11,  4,  4,  2,  3,  5, 10],
#         [11,  4,  2,  1,  7,  6, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  5, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  1,  1,  3,  5,  7, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  3,  2, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  4,  2,  3,  5, 10],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  5,  2, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  8,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  4,  2,  5, 10,  0,  0],
#         [11,  1,  2,  3, 10,  0,  0],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  4,  2,  3, 10,  0,  0],
#         [11,  1,  8,  2,  3,  5, 10],
#         [11,  1,  1,  2,  3,  5, 10],
#         [11,  9,  2,  3, 10,  0,  0],
#         [11,  9,  4,  2,  3,  5, 10]]), [[14.0, 4.0], [90.0, 45.0, 5.0], [105.0, 698.0], [79.0, 13.0], [65.0, 28.0], [22.0, 47.0], [5092.0, 3971.0], [2.0, 4.0], [15.0, 3.0], [45.0, 28.0, 25.0], [5.0, 60.0], [45.0, 33.0], [16.0, 292.0], [6.0, 24.0], [2.0, 3.0, 13.0], [16.0, 33.0, 48.0], [87.0, 16.0], [50.0, 41.0], [15.0, 48.0, 12.0], [14.0, 3.0], [91.0, 38.0], [25.0, 55.0], [14.0, 6.0], [30.0, 6.0], [19.0, 9.0], [4.0, 2.0], [3.0, 20.0, 15.0, 30.0], [9.0, 4.0], [63.0, 49.0], [92.0, 31.0, 20.0], [13.0, 70.0], [2.0, 1.0, 34.0, 37.0], [17.0, 8.0], [47.0, 40.0, 82.0], [210.0, 10.0], [96.0, 8.0], [1.0, 80.0, 400.0], [312.0, 146.0], [432.0, 297.0], [6.0, 5.0], [92.0, 47.0, 38.0], [17.0, 6.0], [12.0, 54.0], [355.0, 5.0], [12.0, 8.0], [1.0, 20.0, 5.0], [12.0, 276.0], [58.0, 21.0], [3.75, 3.0], [5.0, 300.0], [6.0, 2.0, 3.0], [234.0, 9.0], [10.0, 5.0], [20.0, 680.0], [9.0, 49.0], [90.0, 83.0], [36.0, 28.0, 8.0], [65899.0, 119.0], [11.0, 143.0], [11.0, 6.0], [13.0, 6.0], [25.0, 35.0], [72.0, 8.0], [3.0, 21.0, 31.0, 19.0], [134.0, 269.0], [451.0, 150.0], [49.0, 7.0], [18.0, 2.0], [6.0, 9.0, 8.0], [17.0, 35.0], [475.0, 199.0], [757.0, 65.0], [459.0, 9.0], [35.0, 21.0, 34.0], [2.0, 24.0, 46.0], [16.0, 8.0], [13.0, 6.0], [5.0, 7.0], [48.0, 16.0, 18.0], [544.0, 32.0], [14.0, 8.0], [5.0, 35.0], [81.0, 38.0], [354.0, 228.0], [210.0, 3.0, 30.0], [77.0, 32.0, 15.0], [49.0, 35.0], [51.0, 90.0], [87.0, 24.0, 45.0], [436.0, 2.0, 1.0, 132.0, 2.0, 236.0, 2.0], [55.0, 43.0], [420.0, 3.0], [36.0, 73.0], [33.0, 20.0], [1410.0, 1.0, 6908.0], [15.0, 9.0], [5.0, 35.0], [3.0, 34.0, 29.0, 13.0], [14.0, 22.0], [67.0, 64.0], [58.0, 37.0], [91.0, 20.0], [6.0, 57.0], [20.0, 100.0], [48.0, 46.0], [73.0, 55.0], [4.0, 3.0, 10.0], [337.0, 335.0], [18.0, 3.0], [8.0, 2.0, 14.0], [479.0, 134.0], [8.0, 4.0], [125.0, 64.0], [17.0, 7.0], [30.0, 4.0], [52.0, 15.0], [72.0, 6.0], [94.0, 78.0], [54.0, 2.0], [96.0, 14.0, 68.0], [67.0, 17.0], [648.0, 4.0], [81.0, 56.0], [58.0, 24.0], [8.0, 6.0, 5.0], [2.0, 6.0, 10.0], [54.0, 7.0], [51.0, 41.0, 5.0]], [10.0, 9.0, 803.0, 92.0, 93.0, 69.0, 1121.0, 8.0, 12.0, 73.0, 300.0, 78.0, 18.25, 18.0, 11.0, 1.0, 71.0, 91.0, 51.0, 11.0, 53.0, 30.0, 20.0, 5.0, 10.0, 2.0, 65.0, 5.0, 14.0, 41.0, 83.0, 71.0, 136.0, 35.0, 21.0, 12.0, 5.0, 45552.0, 729.0, 30.0, 45.0, 11.0, 66.0, 71.0, 4.0, 100.0, 23.0, 79.0, 1.25, 60.0, 12.0, 26.0, 5.0, 34.0, 441.0, 7.0, 8.0, 66018.0, 13.0, 5.0, 7.0, 10.0, 9.0, 71.0, 403.0, 601.0, 7.0, 9.0, 62.0, 18.0, 276.0, 11.6461538461538, 51.0, 22.0, 70.0, 8.0, 7.0, 35.0, 14.0, 17408.0, 6.0, 7.0, 43.0, 582.0, 7.0, 30.0, 84.0, 39.0, 18.0, 68.0, 98.0, 140.0, 109.0, 13.0, 8318.0, 6.0, 7.0, 76.0, 36.0, 3.0, 95.0, 71.0, 63.0, 5.0, 94.0, 18.0, 11.0, 672.0, 6.0, 6.0, 345.0, 12.0, 61.0, 10.0, 120.0, 780.0, 12.0, 16.0, 56.0, 28.0, 84.0, 162.0, 25.0, 34.0, 53.0, 18.0, 7.71428571428571, 2.0])

# %%
from torchtext.vocab import GloVe, FastText

global_vectors = GloVe(name='840B', dim=300)
embed_matrix = torch.zeros(ids+1, 300)
for word, i in vocab_to_id.items():
    embed_matrix[i] = global_vectors[word]

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self,
                 emb_size: int,
                 dropout: float,
                 maxlen: int = 250):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2)* math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: torch.Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0), :])

# helper Module to convert torch.Tensor of input indices into corresponding torch.Tensor of token embeddings
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size, embed = None):
        super(TokenEmbedding, self).__init__()

        if embed != None:
            self.embedding = nn.Embedding.from_pretrained(embed)
        else:
            self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size

    def forward(self, tokens: torch.Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)

# Seq2Seq Network
class Seq2SeqTransformer(nn.Module):
    def __init__(self,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 emb_size: int,
                 nhead: int,
                 src_vocab_size: int,
                 tgt_vocab_size: int,
                 dim_feedforward: int = 512,
                 dropout: float = 0.15,
                 embed = None):
        super(Seq2SeqTransformer, self).__init__()
        self.transformer = nn.Transformer(d_model=emb_size,
                                       nhead=nhead,
                                       num_encoder_layers=num_encoder_layers,
                                       num_decoder_layers=num_decoder_layers,
                                       dim_feedforward=dim_feedforward,
                                       dropout=dropout,
                                       activation = 'gelu')
        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size, embed)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(
            emb_size, dropout=dropout)
        self.attn = nn.Linear(300, 1)

    def forward(self,
                src: torch.Tensor,
                trg: torch.Tensor,
                src_mask: torch.Tensor,
                tgt_mask: torch.Tensor,
                src_padding_mask: torch.Tensor,
                tgt_padding_mask: torch.Tensor,
                memory_key_padding_mask: torch.Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))    # N * seq_len * 300 
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        outs = self.transformer(src_emb, tgt_emb, src_mask, tgt_mask, None,
                                src_padding_mask, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: torch.Tensor, src_mask: torch.Tensor):
        return self.transformer.encoder(self.positional_encoding(
                            self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: torch.Tensor, memory: torch.Tensor, tgt_mask: torch.Tensor):
        return self.transformer.decoder(tgt=self.positional_encoding(
                          self.tgt_tok_emb(tgt)), memory=memory,
                          tgt_mask=tgt_mask)

# %%
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=DEVICE)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask


def create_mask(src, tgt):
    src_seq_len = src.shape[0]
    tgt_seq_len = tgt.shape[0]

    tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
    src_mask = torch.zeros((src_seq_len, src_seq_len),device=DEVICE).type(torch.bool)

    src_padding_mask = (src == PAD_IDX).transpose(0, 1)
    tgt_padding_mask = (tgt == PAD_IDX).transpose(0, 1)
    return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

# %%
print(vocab_to_id['number1'])
import nltk
nltk.download('stopwords')
# Out:
# 9
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /raid/home/kawinm/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#torch.manual_seed(0)

SRC_VOCAB_SIZE = ids+1
TGT_VOCAB_SIZE = idt+2
EMB_SIZE = 512
NHEAD = 8
FFN_HID_DIM = 512
BATCH_SIZE = 128
NUM_ENCODER_LAYERS = 4
NUM_DECODER_LAYERS = 4
DEVICE = torch.device("cuda:1")
model = Seq2SeqTransformer(NUM_ENCODER_LAYERS, NUM_DECODER_LAYERS, EMB_SIZE,
                                 NHEAD, SRC_VOCAB_SIZE, TGT_VOCAB_SIZE, FFN_HID_DIM)


model = model.to(DEVICE)

loss_fn = torch.nn.CrossEntropyLoss(ignore_index=PAD_IDX)

opt = torch.optim.AdamW(model.parameters(), lr=0.0001)

# %%
def calculate_metric(ans, ip):
    out = []
    for b in range(len(ans)):
        stack = []
        expression = ans[b]
        # iterate over the string in reverse order
        #print(expression[::-1], ip[b])
        for c in expression[::-1]:
    
            # push operand to stack
            if "number" in c:
                idx = int(c[-1])
                if len(ip[b]) <= idx:
                    stack.append(int(ip[b][0]))
                    continue
                stack.append(int(ip[b][idx]))
            elif c in "+-/*":
                try:
                    o1 = stack.pop()
                    o2 = stack.pop()
                except:
                    continue
    
                if c == '+':
                    stack.append(o1 + o2)
                elif c == '-':
                    stack.append(o1 - o2)
                elif c == '*':
                    stack.append(o1 * o2)
                elif c == '/':
                    try:
                        stack.append(o1 / o2)
                    except:
                        print(ans[b], ip[b])
        try:
            out.append(stack.pop())
        except:
            out.append(int(ip[b][0]) + int(ip[b][1]))
    return out

# %%
id_to_vocab_target = {}
for i, v in vocab_target_to_id.items():
    id_to_vocab_target[v] = i
id_to_vocab_target[0] = "<pad>"
id_to_vocab_target[idt] = "EOS"
id_to_vocab_target[idt+1] = "<BOS>"
#id_to_vocab_target

# %%
# ----------- Main Training Loop -----------
max_epoch = 20

best_test_acc = 0
for ep in range(max_epoch):

    epoch_loss = 0

    model.train()
    train_labels = []
    train_pred = []
    correct_train, B_train = 0, 0
    for cont, ques, ans, ip, out in train_loader:
        loss = 0
        cont = cont.to(DEVICE).transpose(0,1)
        ques = ques.to(DEVICE).transpose(0,1)
        ans = ans.to(DEVICE).transpose(0,1)

        ans_inp = ans[:-1, :]
        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(cont, ans_inp)

        logits = model(cont, ans_inp, src_mask, tgt_mask,src_padding_mask, tgt_padding_mask, src_padding_mask)

        opt.zero_grad()

        ans_out = ans[1:, :]
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), ans_out.reshape(-1))

        loss.backward()
        opt.step()

        epoch_loss += float(loss)

        pred = []
        ans = ans.transpose(0,1)
        logits = logits.transpose(0,1)
        for b in range(ans.shape[0]):
            p = []
            for i in range(ans.shape[1]-1):
                p.append(id_to_vocab_target[torch.argmax(logits[0,i,:]).item()])
            pred.append(p)
        
        if ep > 2:
            outt = calculate_metric(pred, ip)
            #print(outt)
            for i in range(len(out)):
                #print(outt[i], out[i])
                if float(outt[i]) == float(out[i]):
                    correct_train += 1
                else:
                    #print(outt[i], out[i])
                    pass
            B_train += len(out)       

    print("Epoch: ", ep+1, " Training Loss: ", epoch_loss/ len(train_loader))
    #print("Train accuracy: ", accuracy_score(train_labels, train_pred)*50)
    if ep > 2:
        print("Train EM: ", (correct_train/ B_train)*100)

    epoch_loss = 0

    model.eval()
    train_labels = []
    train_pred = []
    correct_train, B_train = 0, 0
    for cont, ques, ans, ip, out in val_loader:
        loss = 0
        cont = cont.to(DEVICE).transpose(0,1)
        ques = ques.to(DEVICE).transpose(0,1)
        ans = ans.to(DEVICE).transpose(0,1)

        ans_inp = ans[:-1, :]
        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(cont, ans_inp)

        logits = model(cont, ans_inp, src_mask, tgt_mask,src_padding_mask, tgt_padding_mask, src_padding_mask)

        ans_out = ans[1:, :]
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), ans_out.reshape(-1))


        epoch_loss += float(loss)

        pred = []
        ans = ans.transpose(0,1)
        logits = logits.transpose(0,1)
        for b in range(ans.shape[0]):
            p = []
            for i in range(ans.shape[1]-1):
                p.append(id_to_vocab_target[torch.argmax(logits[0,i,:]).item()])
            pred.append(p)
        
        if ep > 2:
            outt = calculate_metric(pred, ip)
            for i in range(len(out)):
                if float(outt[i]) == float(out[i]):
                    correct_train += 1
            B_train += len(out)       

    print("Epoch: ", ep+1, " Val Loss: ", epoch_loss/ len(val_loader))
    #print("Train accuracy: ", accuracy_score(train_labels, train_pred)*50)
    if ep > 2:
        print("Val EM: ", (correct_train/ B_train)*100)
# Out:
# Epoch:  1  Training Loss:  1.982847707612174
# Epoch:  1  Val Loss:  1.4555144906044006
# Epoch:  2  Training Loss:  1.2276159865515572
# Epoch:  2  Val Loss:  0.8310635983943939
# Epoch:  3  Training Loss:  0.7801089201654706
# Epoch:  3  Val Loss:  0.6838230788707733
# Epoch:  4  Training Loss:  0.6396665828568595
# Train EM:  10.459183673469388
# Epoch:  4  Val Loss:  0.5844732820987701
# Val EM:  15.384615384615385
# Epoch:  5  Training Loss:  0.5585768265383584
# Train EM:  14.668367346938776
# Epoch:  5  Val Loss:  0.5439048856496811
# Val EM:  2.051282051282051
# Epoch:  6  Training Loss:  0.5108025244304112
# Train EM:  21.1734693877551
# Epoch:  6  Val Loss:  0.5083577632904053
# Val EM:  3.5897435897435894
# Epoch:  7  Training Loss:  0.4518703137125288
# Train EM:  14.668367346938776
# Epoch:  7  Val Loss:  0.43260714411735535
# Val EM:  22.05128205128205
# Epoch:  8  Training Loss:  0.4141032099723816
# Train EM:  11.224489795918368
# Epoch:  8  Val Loss:  0.4587138891220093
# Val EM:  20.51282051282051
# Epoch:  9  Training Loss:  0.3788640456540244
# Train EM:  17.98469387755102
# Epoch:  9  Val Loss:  0.39826636016368866
# Val EM:  1.5384615384615385
# Epoch:  10  Training Loss:  0.367441999060767
# Train EM:  14.158163265306122
# Epoch:  10  Val Loss:  0.34732432663440704
# Val EM:  10.256410256410255
# Epoch:  11  Training Loss:  0.3417786487511226
# Train EM:  16.3265306122449
# Epoch:  11  Val Loss:  0.3530849516391754
# Val EM:  5.128205128205128
# Epoch:  12  Training Loss:  0.3424473064286368
# Train EM:  11.096938775510203
# Epoch:  12  Val Loss:  0.3394874334335327
# Val EM:  14.358974358974358
# Epoch:  13  Training Loss:  0.320108026266098
# Train EM:  11.607142857142858
# Epoch:  13  Val Loss:  0.32764388620853424
# Val EM:  7.6923076923076925
# Epoch:  14  Training Loss:  0.29680892399379183
# Train EM:  7.3979591836734695
# Epoch:  14  Val Loss:  0.3451216369867325
# Val EM:  4.615384615384616
# Epoch:  15  Training Loss:  0.32168247018541607
# Train EM:  11.35204081632653
# Epoch:  15  Val Loss:  0.34197257459163666
# Val EM:  7.6923076923076925
# Epoch:  16  Training Loss:  0.3101758041552135
# Train EM:  13.77551020408163
# Epoch:  16  Val Loss:  0.39297039806842804
# Val EM:  21.53846153846154
# Epoch:  17  Training Loss:  0.2811558927808489
# Train EM:  11.35204081632653
# Epoch:  17  Val Loss:  0.348882332444191
# Val EM:  16.41025641025641
# Epoch:  18  Training Loss:  0.26809710051332203
# Train EM:  11.73469387755102
# Epoch:  18  Val Loss:  0.30850648880004883
# Val EM:  18.974358974358974
# Epoch:  19  Training Loss:  0.2815601719277246
# Train EM:  10.204081632653061
# Epoch:  19  Val Loss:  0.344362810254097
# Val EM:  10.256410256410255
# Epoch:  20  Training Loss:  0.2455775567463466
# Train EM:  15.306122448979592
# Epoch:  20  Val Loss:  0.34682944416999817
# Val EM:  1.0256410256410255

# %%
print(B_train, correct_train)
# Out:
# 195 0

# %%
# ----------- Main Training Loop -----------
max_epoch = 1

best_test_acc = 0
for ep in range(max_epoch):

    epoch_loss = 0

    model.train()
    train_labels = []
    train_pred = []
    correct_train, B_train = 0, 0
    for cont, ques, ans, ip, out in tqdm(val_loader):
        loss = 0
        cont = cont.to(DEVICE)
        ques = ques.to(DEVICE)
        ans = ans.to(DEVICE)

        ans_inp = ans[:, :-1]
        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(cont, ans_inp)

        logits = model(cont, ans_inp, src_mask, tgt_mask,src_padding_mask, tgt_padding_mask, src_padding_mask)

        opt.zero_grad()

        ans_out = ans[:, 1:]
        loss = loss_fn(logits.reshape(-1, logits.shape[-1]), ans_out.reshape(-1))


        epoch_loss += float(loss)

        for b in range(ans.shape[0]):
            p = [[]]
            for i in range(ans.shape[1]-1):
                print(id_to_vocab_target[torch.argmax(logits[b,i,:]).item()], end=" ")
                p[0].append(id_to_vocab_target[torch.argmax(logits[b,i,:]).item()])
                print(id_to_vocab_target[ans[b, i].item()])
            print()
            outt = calculate_metric(p, [ip[b]])
            if abs(float(outt[0]) - float(out[b])) < 0.0001:
                print("incorrect, ", float(outt[0]),float(out[b]))
            print(outt, out[b])
        #y_hat = torch.softmax(y_hat, dim = 1).argmax(dim=1)

        #correct, B = exact_match(y_hat, yb)
        #correct_train += correct
        #B_train += B
        #train_labels.extend(yb.cpu().detach().numpy())
        #train_pred.extend(y_hat.cpu().detach().numpy())

    print("Epoch: ", ep+1, " Training Loss: ", epoch_loss)
    #print("Train accuracy: ", accuracy_score(train_labels, train_pred)*100)
    #print("Train EM: ", (correct_train/ B_train)*100)
# Out:
#  25%|██▌       | 1/4 [00:00<00:00,  6.99it/s]
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  59.0 59.0
# [59] 59.0
# - <BOS>
# number0 /
# number0 +
# number0 number1
# EOS number2
# EOS number0
#
# [0] 3.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [5] 15.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 14.0
# - <BOS>
# number0 /
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 9.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [13] 19.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [15] 6.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 42.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [126] 582.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 30.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  2.0 2.0
# [2] 2.0
# - <BOS>
# number1 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [0] 244.0
# - <BOS>
# / *
# number1 -
# number1 number0
# number2 number1
# EOS number2
#
# [-3.0] 32.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-7] 17.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-29] 720.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [18] 703.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [19] 65.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  25.0 25.0
# [25] 25.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  5.0 5.0
# [5] 5.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [25] 6.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  5.0 5.0
# [5] 5.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  7.0 7.0
# [7] 7.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 39.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-7] 11.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [30] 7.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 73.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 3.0
# - <BOS>
# number0 +
# number1 number0
# EOS number2
# <pad> EOS
# <pad> <pad>
#
# [1409] 8318.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 17.0
# - <BOS>
# number0 /
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 7.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [3] 41.0
# - <BOS>
# / *
# number1 number0
# number2 number1
# <pad> EOS
# <pad> <pad>
#
# [409] 4764.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 12.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  5.0 5.0
# [5] 5.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 43.0
# - <BOS>
# number0 /
# number3 number2
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [0] 8.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [19] 49.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  11.0 11.0
# [11] 11.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  207.0 207.0
# [207] 207.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  688.0 688.0
# [688] 688.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  21.0 21.0
# [21] 21.0
# - <BOS>
# number0 +
# / *
# number2 number1
# EOS number2
# EOS number0
#
# [13] 41.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number3 number2
# EOS number3
#
# [0] 32.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [20] 5.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 95.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [244] 952.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-2] 8.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 396.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  1.0 1.0
# [1] 1.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [396] 37.0
# - <BOS>
# number0 +
# number0 -
# number0 number2
# number0 number1
# EOS number0
#
# [0] 61.0
# - <BOS>
# number0 +
# number0 -
# number0 number2
# EOS number1
# EOS number0
#
# [0] 37.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 53.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [261] 30.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [3] 18.0
# / <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [1.0] 44.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  99.0 99.0
# [99] 99.0
# - <BOS>
# number0 /
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 1.2
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  7.0 7.0
# [7] 7.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [66] 12.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 13.0
# - <BOS>
# / *
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [-0.5] 6.0
# - <BOS>
# number0 /
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 5.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-8] 82.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-3] 70.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [89] 95.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  13.0 13.0
# [13] 13.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 52.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  9.0 9.0
# [9] 9.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 47.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  1121.0 1121.0
# [1121] 1121.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [24] 5.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  80.0 80.0
# [80] 80.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 31.0
# - <BOS>
# number0 +
# / *
# number1 number0
# number2 number1
# EOS number2
#
# [4.875] 62.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [13] 19.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [12] 18.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [37] 93.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 18.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  276.0 276.0
# [276] 276.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [20] 74.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  4.0 4.0
# [4] 4.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [20] 32.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 64.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 83.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [7] 13.0
# - <BOS>
# number0 /
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 3.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  3.0 3.0
# [3] 3.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [2] 16.0
# - <BOS>
# number0 -
# number1 number0
# EOS number3
# <pad> EOS
# <pad> <pad>
#
# [28] 7.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 14.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-11] 63.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [69] 87.0
# - <BOS>
# / *
# number1 /
# number0 number1
# number2 number0
# EOS number2
#
# [-5.0] 7.74
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [470] 19.8
# - <BOS>
# number0 /
# number2 number0
# EOS number2
# <pad> EOS
# <pad> <pad>
#
# [168] 13.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [48] 9.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [110] 1200.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 26.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-13] 140.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [31] 77.0
# - <BOS>
# number0 +
# number0 +
# number2 number1
# number2 number2
# EOS number3
#
# [0] 76.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  2.0 2.0
# [2] 2.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 39.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  59.0 59.0
# [59] 59.0
# - <BOS>
# number0 -
# number1 number2
# number1 number0
# <pad> EOS
# 100%|██████████| 4/4 [00:00<00:00,  9.94it/s]
# <pad> <pad>
#
# [33] 11.0
# - <BOS>
# number0 +
# number2 number1
# EOS number2
# <pad> EOS
# <pad> <pad>
#
# [-53] 92.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  128.0 128.0
# [128] 128.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 32.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [60] 21.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 22.0
# - <BOS>
# number0 -
# number1 number2
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-441] 9.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  176.0 176.0
# [176] 176.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 55.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  8.0 8.0
# [8] 8.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [18] 3.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 31.0
# - <BOS>
# / *
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [-1.5] 30.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  66.0 66.0
# [66] 66.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [13] 113.0
# - <BOS>
# number0 /
# number0 -
# number1 number0
# number2 number1
# EOS number3
#
# [0] 9.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  45.0 45.0
# [45] 45.0
# - <BOS>
# / *
# number1 number0
# number1 /
# number1 number2
# number2 number1
#
# [-4.0] 21.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [248] 63.0
# - <BOS>
# number0 -
# number1 number2
# number1 number0
# <pad> EOS
# <pad> <pad>
#
# [-1] 11.0
# - <BOS>
# number0 -
# EOS number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [157] 23.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [65780] 66018.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [18] 98.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  54.0 54.0
# [54] 54.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [11] 19.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  39.0 39.0
# [39] 39.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [32] 320.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 1.14
# - <BOS>
# number0 +
# number2 number1
# EOS number3
# <pad> EOS
# <pad> <pad>
#
# [86] 40.0
# - <BOS>
# number0 -
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 2.0
# - <BOS>
# number0 /
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 5.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-1] 30.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 50.0
# - <BOS>
# / *
# number1 -
# number2 number1
# number0 number2
# EOS number0
#
# [-0.33333333333333326] 4.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 30.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number3 number2
# EOS number1
#
# [0] 19.0
# - <BOS>
# number0 -
# number1 number0
# EOS number3
# <pad> EOS
# <pad> <pad>
#
# [8] 23.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-8] 36.0
# - <BOS>
# number0 +
# number1 number0
# number2 number1
# <pad> EOS
# <pad> <pad>
#
# [17] 73.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  3264.0 3264.0
# [3264] 3264.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [1] 11.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [38] 62.0
# - <BOS>
# number0 +
# / *
# number2 number1
# EOS number2
# EOS number0
#
# [5] 21.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  67.0 67.0
# [67] 67.0
# - <BOS>
# number0 -
# number1 number0
# number2 *
# number1 number2
# number2 number1
#
# [56] 12.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-8] 62.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 14.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [4] 96.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [150] 700.0
# - <BOS>
# number0 /
# number0 number1
# EOS number2
# <pad> EOS
# <pad> <pad>
#
# [0] 5.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  4.0 4.0
# [4] 4.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [154] 9.55555555555556
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  43.0 43.0
# [43] 43.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [8] 16.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  7.0 7.0
# [7] 7.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [40] 6.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 48.0
# - <BOS>
# number0 +
# number2 number1
# EOS number2
# <pad> EOS
# <pad> <pad>
#
# [83] 82.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [16] 80.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number2 number1
# EOS number2
#
# [0] 9.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 18.0
# - <BOS>
# number0 +
# number0 -
# number1 number0
# number2 number1
# EOS number3
#
# [0] 27.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-21] 91.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [23] 420.0
# - <BOS>
# number0 /
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 8.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [4] 32.0
# - <BOS>
# number0 -
# number1 number0
# number2 +
# number2 number1
# EOS number2
#
# [225] 90.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-1] 5.0
# - <BOS>
# number0 -
# number0 -
# number1 number0
# number3 number2
# EOS number1
#
# [0] 35.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [77] 498.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [275] 8484.0
# - <BOS>
# number0 /
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 4.0
# - <BOS>
# number0 /
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 12.0
# - <BOS>
# number0 /
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 34.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [242] 892.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [144] 280.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-1] 7.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  68.0 68.0
# [68] 68.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [738] 10.0
# - <BOS>
# number0 -
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# incorrect,  8.0 8.0
# [8] 8.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [37] 360.0
# - <BOS>
# number0 /
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [350] 71.0
# - <BOS>
# number0 -
# number0 number1
# EOS number0
# <pad> EOS
# <pad> <pad>
#
# [0] 24.0
# - <BOS>
# - *
# number1 number0
# number2 number1
# <pad> EOS
# <pad> <pad>
#
# [69] 540.0
# - <BOS>
# number0 +
# number0 +
# number2 number1
# EOS number2
# EOS number3
#
# [0] 65.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
# <pad> EOS
# <pad> <pad>
#
# [-74] 480.0
# - <BOS>
# number0 +
# number0 +
# number1 number0
# number2 number1
# EOS number2
#
# [0] 51.0
# - <BOS>
# number0 *
# number1 number0
# EOS number1
#
# [-352] 1424.0
# - <BOS>
# number0 +
# number1 number0
# EOS number1
#
# [9] 15.0
# - <BOS>
# number0 -
# number0 number1
# EOS number2
#
# [0] 7.0
# Epoch:  1  Training Loss:  1.7813825905323029

# %%
# function to generate output sequence using greedy algorithm
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    src = src.to(DEVICE)
    src_mask = src_mask.to(DEVICE)

    memory = model.encode(src, src_mask)[:,0,:].unsqueeze(dim=1)
    #print(memory.shape)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(DEVICE)
    for i in range(max_len-1):
        memory = memory.to(DEVICE)
        tgt_mask = (generate_square_subsequent_mask(ys.size(0))
                    .type(torch.bool)).to(DEVICE)

        #print(ys.shape, memory.shape, tgt_mask.shape)
        out = model.transformer.decoder(tgt=model.positional_encoding(
                          model.tgt_tok_emb(ys)), memory=memory, tgt_mask=tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()

        ys = torch.cat([ys,
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == idt:
            break
    return ys

model.train()
for cont, ques, ans, ip, out in tqdm(train_loader):
    loss = 0
    cont = cont.to(DEVICE)[0,:]
    ques = ques.to(DEVICE)
    ans = ans.to(DEVICE)

    cont.unsqueeze(dim=1)
    #src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(cont, ans_inp)
    #print(cont.shape)
    num_tokens = cont.shape[0]
    src_mask = (torch.zeros(num_tokens, num_tokens)).type(torch.bool)
    #print(src_mask.shape)

    print(greedy_decode(model, cont, src_mask, cont.shape[0]+5, idt+1))
    break

        

# actual function to translate input sentence into target language
def translate(model: torch.nn.Module, src_sentence: str):
    model.eval()
    src = text_transform[SRC_LANGUAGE](src_sentence).view(-1, 1)
    num_tokens = src.shape[0]
    src_mask = (torch.zeros(num_tokens, num_tokens)).type(torch.bool)
    tgt_tokens = greedy_decode(
        model,  src, src_mask, max_len=num_tokens + 5, start_symbol=BOS_IDX).flatten()
    return " ".join(vocab_transform[TGT_LANGUAGE].lookup_tokens(list(tgt_tokens.cpu().numpy()))).replace("<bos>", "").replace("<eos>", "")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# tensor([[11],
#         [ 3],
#         [ 5],
#         [10]], device='cuda:1')
